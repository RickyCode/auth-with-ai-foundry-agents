# %%
import json
import os

import requests

# %%
os.environ[
    "BALANCE_API_BASE_URL"
] = "https://microsoft-foundry-playground-balance-mock-api.9uxguk.easypanel.host"

# %%
os.environ.get("BALANCE_API_BASE_URL", "http://localhost:8000")

# %%
def get_base_url() -> str:
    return os.environ.get("BALANCE_API_BASE_URL", "http://localhost:8000")


def call_balance_api(customer_id: str) -> dict:
    url = f"{get_base_url().rstrip('/')}/api/balance"
    payload = {"customer_id": customer_id}
    response = requests.post(url, json=payload, timeout=5)
    try:
        data = response.json()
    except json.JSONDecodeError:
        data = {"raw_text": response.text}
    return {
        "status_code": response.status_code,
        "data": data,
    }

# %%
result = call_balance_api("customer-002")
print(json.dumps(result, indent=2, ensure_ascii=False))

# %% [markdown]
# ---
# ## Tokens Test

# %%
import os
import requests
import dotenv

# %%
dotenv.load_dotenv()
# Out:
# True

# %%
KEYCLOAK_BASE_URL = os.getenv("KEYCLOACK_BASE_URL")
REALM_NAME = os.getenv("REALM_NAME")
CLIENT_ID = os.getenv("CLIENT_ID")
CLIENT_SECRET = os.getenv("CLIENT_SECRET")
USER_1_NAME = os.getenv("USER_1_NAME")
USER_2_NAME = os.getenv("USER_2_NAME")
USER_1_PASSWORD = os.getenv("USER_1_PASSWORD")
USER_2_PASSWORD = os.getenv("USER_2_PASSWORD")

TOKEN_URL = f"{KEYCLOAK_BASE_URL}/realms/{REALM_NAME}/protocol/openid-connect/token"

# %%
def get_access_token(username: str, password: str):
    data = {
        "grant_type": "password",
        "client_id": CLIENT_ID,
        "client_secret": CLIENT_SECRET,
        "username": username,
        "password": password,
    }

    headers = {
        "Content-Type": "application/x-www-form-urlencoded"
    }

    response = requests.post(TOKEN_URL, data=data, headers=headers)

    if response.status_code != 200:
        raise Exception(f"Error {response.status_code}: {response.text}")

    return response.json()["access_token"]

# %%
token = get_access_token(USER_1_NAME, USER_1_PASSWORD)
print(token)
# Out:
# 'eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJaMno2VGVrR1dtRDEzdEhuQ2xCd3F5a0lfSG45VlhuN1JzNndfcUc3SC0wIn0.....VXsNNlXlz2FfO4Iox7GzakTg6GJoTlRtRHg9ZNbvI8hEH_kwmxIXSjiQIRUGsgkv7JKA-T5a6if7lvqm1yK53fElOQY2dAjszKig4eRPXH90m-8vD4e3fTaSDBe7PDG1bWP0KXrm_H22AtOh9rEKSKe_k062bvlLIJXcPPBGldEq_QhHDR713YbJqTSkn0aUEPNY30Aqx7REuO1VxdqnqXGsuAnYaq2ImK8SJ7Q4Za7bnmUPzd12LbB38KrYuwPT22aM0TTlwORUymVA9ojayPC_M0KYaP4oBNANwNAu4x0Jcb6RqlXT1QvXRGdW0WYFLhG50lSH5rgPbyuuQCoIrw'

# %%
token = get_access_token(USER_2_NAME, USER_2_PASSWORD)
print(token)
# Out:
# eyJhbGciOiJSUzI1NiIsInR5cCIgOiAiSldUIiwia2lkIiA6ICJaMno2VGVrR1dtRDEzdEhuQ2xCd3F5a0lfSG45VlhuN1JzNndfcUc3SC0wIn0.....xlwHhOVBy3_O3rtrT96xI1RaARp4Npj0vAfo7Pcq_mGDvryKoVtLjuawc8fQxyV2ZxGdJj-vJwrDuFUKINnBEEQI1l0IF7E0iESDfgU54eTYNaNTxaLYQd3JHvsr-K32c5jlS_lxQqkMspbK2TJ9VucXjueJJqjYMmzBbFjw4VCkunFY_BcH0TQr8FTUQdj6KADzz0KrTbSyczcS_GvyaLDa2J9P_kZIsXOsrZw4UyyqiSzWNGEqj0HMRUYBqDlEZaCqVMQc6sSBWKgG0XDJ4J5sV8MoaU3Ux40ZVChxgSQvrwGFIq7TfJT-JP5xiahmwszQ_NXxPHDCM3k3D9aqnA

# %% [markdown]
# ### Use Token to Call API

# %%
response = requests.post(
    "http://localhost:8000/api/balance",
    headers={
        "Authorization": f"Bearer {token}",
        "Content-Type": "application/json",
    },
    json={},
    timeout=10,
)

print(response.status_code)
print(response.text)
# Out:
# 200
# 87500.0
